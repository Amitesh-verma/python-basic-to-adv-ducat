# %%
# agenda:-.
# import module
# decorator function
# generator function

# %%
# import and export
# dealing with files

# step:1:- creating folder on desktop
# step:1:- open the folder and remove the path and enter the :-   code . 
# step:3:- creatint the file usa.py and india.py 
# if we want open the terminal in vscode then we have to press ctrl+`
# if we want to run the python code with the cmd then we have to write with (python filename.py)

# %%
# decorator function
def change(a):
    def inner():
        return 100
    return inner
@change
def raman():
    return 20
raman()
# Out:
# 100

# %%
b=raman()
print(b+100)
# Out:
# 200
