# %% [markdown]
# Type conversion

# %% [markdown]
# Converting one data type to another data type

# %%
a = "2.0"
type(a)
a = int(float((a)))
a
# Out:
# 2

# %%
a = 2.0
a = str(a)
a
# Out:
# '2.0'

# %%
a = '2.0'
a = float(a)
a
# Out:
# 2.0

# %%
a = 2.0
a = complex(a)
a
# Out:
# (2+0j)

# %%
fruit = ["apple","banana","pineapple","bluebarry"]
print(type(fruit))
fruit = tuple(fruit)
print(type(fruit))
fruit
# Out:
# <class 'list'>
# <class 'tuple'>
# ('apple', 'banana', 'pineapple', 'bluebarry')

# %%
fruit = ["apple","banana","pineapple","bluebarry"]
fruit = set(fruit)
print(fruit)
# Out:
# {'banana', 'apple', 'pineapple', 'bluebarry'}

# %%
fruit = ["apple","banana","pineapple","bluebarry","apple","banana","pineapple","bluebarry"]
fruit =list(set(fruit))
fruit
# Out:
# ['banana', 'apple', 'pineapple', 'bluebarry']
