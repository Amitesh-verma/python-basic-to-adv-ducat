# %%
# Create a program using global keyword to modify a variable from inside  a function.

count = 0
def incre_count():
    global count
    count+=1

print('before',count)
incre_count()
print('after',count)
# Out:
# before 0
# after 1

# %%
# None--

# None means no value.

def greet():
    
    print("Hello Saumya!")
          
result = greet()

print(result)
# Out:
# Hello Saumya!
# None

# %%
def greet():
    print('hello miu')

# %%
# creating the function
# : indicating that starting of the body statement
# 1tab=4spaces
def raman(): #parenthesis :- parameter
    print('hi class')

# %%
# calling the function
raman()
# Out:
# hi class

# %%
# function with parameter
def raman(name,city): #parameter
    print(name,city)

raman('raman','noida') #calling the function  #arguments
# Out:
# raman noida

# %%
# calling function in another function
def a():
    print('hi i am a')
def b():
    print('hi i am b')
    a()
    
b()
# Out:
# hi i am b
# hi i am a

# %%
def a():
    print('hi i am a')
    def b():
        print('hi i am b')
    b()
a()
# Out:
# hi i am a
# hi i am b

# %%
# print vs return
a=print(10)
print(a)
# Out:
# 10
# None

# %%
def raman():
    a=5
b=raman()
print(b)
# Out:
# None

# %%
# return data store karta hoon
# after return statement function terminates
def a():
    return 10
m=a()
print(10+m)
# Out:
# 20

# %%
# default parameter
def raman(name='aditya'):
    print(name)
raman('raman') #argument
# Out:
# raman

# %%
# args and kwargs
# args
# * indicates all
def aman(*a):
    print(a[-1])
aman(1,2,3,4,5) #argument
# Out:
# 5

# %%
# kwargs
def b(**a):
    print(a)
b(name='raman',city='noida')
# Out:
# {'name': 'raman', 'city': 'noida'}

# %%
# doc string
def b():
    '''is function me adding kar rahe hai'''
    print(10+20+30)

# %%
print(b.__doc__)
# Out:
# is function me adding kar rahe hai

# %%
# calculator
# user 2 number
def ty(a,b):
    print(a+b)
a=int(input('enter the a value'))
b=int(input('enter the a value 2'))
ty(a,b)
# Out:
# 10

# %%
# local and global scope /variable
m=50 #global variable
def g():
    print(m)
g()
print(m)
# Out:
# 50
# 50

# %%
# local scope/variable
def h():
    v=10 #local scope
h()
print(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3     v=10 #local scope
#       4 h()
# ----> 5 print(v)
#
# NameError: name 'v' is not defined

# %%
# global and local variable
te=10
def t():
    z=50
    print(te+z)
t()
# Out:
# 60

# %%
# global keyword
# convert local to global
def gt():
    global n
    n=50
gt()
print(n)
# Out:
# 50
