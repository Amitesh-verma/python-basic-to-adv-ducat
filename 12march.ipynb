# %% [markdown]
# Print

# %%
print('hey', 'buddy')
# Out:
# hey buddy

# %%
# hey-buddy
print('hey-buddy')
# Out:
# hey-buddy

# %%
print('hey','buddy',sep="-")
# Out:
# hey-buddy

# %%
print(3,5,sep="-")
# Out:
# 3-5

# %%
print('hey','buddy', sep="***")
# Out:
# hey***buddy

# %%
print('hey',sep="\n")
print('buddy',sep='\n')

print('*',sep='\n')
print('**',sep='\n')
print('***',sep='\n')
print('****',sep='\n')
print('*****',sep='\n')
# Out:
# hey
# buddy
# *
# **
# ***
# ****
# *****

# %%
print('hey\n',' buddy')
# Out:
# hey
#   buddy

# %%
print('hey','buddy' ,end="***")
# Out:
# hey buddy***

# %%
print('hey','buddy',sep="\t")
# Out:
# hey	buddy

# %%
print("this is rishi's property")
# Out:
# this is rishi's property

# %%
print('''this is rishi's property for "sell"''')
# Out:
# this is rishi's property for "sell"

# %%
# type()
# 3 main data types 
# number

# %%
a =40
type(a)
# Out:
# int

# %%
a = 23.45
type(a)
# Out:
# float

# %%
a = 5+6j
type(a)
# Out:
# complex

# %%
a = "sdhgfhsdg"
type(a)
# Out:
# str

# %%
a = True
type(a)
# Out:
# bool

# %%
a =30

# %%
b=34

# %%
print(a)
# Out:
# 30

# %%
print(a+b)
# Out:
# 64

# %%
print(a-b)
# Out:
# -4

# %%
print(a*b)
# Out:
# 1020
