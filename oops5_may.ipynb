# %%
# oops
# inheritance

class parent(child):
    def gussa(self):
        print('bahot hai')
class child:
    def achhe_talks(self):
        print('hi all')
b=child()
b.achhe_talks()
b.gussa()


# class Animal:
#     def eat(self):
#         print("Khana khata hai")

# class Dog(Animal):  # Dog inherits Animal
#     def bark(self):
#         print("Bhau bhau")

# d = Dog()
# d.eat()   # parent ka method
# d.bark()  # apna method

# %%
# polymorphism

class Dog:
    def sound(self):
        return "Bhau Bhau"

class Cat:
    def sound(self):
        return "Meow Meow"

animals = list(1,2,3,4)
# animals=list(dog(),cat())
# print(animals)
for a in animals:
    print(a)

# %%
# Abstraction
from abc import ABC, abstractmethod

class Vehicle(ABC):
    
    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        print("Car start ho gayi")

c = Car()
c.start()

# %%
# Encapsulation
class Bank:
    def __init__(self):
        self.__balance = 1000   # private variable

    def deposit(self, amount):
        self.__balance += amount

    def get_balance(self):
        return self.__balance

b = Bank()
b.deposit(500)
# b.__balance
print(b.get_balance())
# Out:
# 1500

# %%
# Encapsulation (Wrapping Data + Methods Together)

# Encapsulation means:

# keeping data and methods inside one class,
# and controlling direct access to data.
# Key Point

# __marks is private.
# You should access it using methods, not directly.

# Think of encapsulation like a capsule:

# data + functions packed together safely.

# __marks # private variable hai 

class Student:
    def __init__(self):
        self.__marks = 90   # private variable

    def show_marks(self):
        print(self.__marks)

s = Student()
s.show_marks()
# Out:
# 90

# %%
# Abstraction (Hiding Internal Details)

# Abstraction means:

# showing only important things,
# hiding complex implementation.

# You only use start().
# You do not need to know:

# engine process,
# fuel system,
# battery working.

# That hidden complexity is abstraction.

class Car:
    def start(self):
        print("Car started")

c = Car()
c.start()
# Out:
# Car started

# %%
# | Concept       | Meaning         |
# | ------------- | --------------- |
# | Encapsulation | Protect data    |
# | Abstraction   | Hide complexity |

# %%
# | Concept      | Very Easy Meaning                            |
# | ------------ | -------------------------------------------- |
# | Inheritance  | One class gets properties from another class |
# | Polymorphism | One thing behaves in different ways          |

# %%
# Inheritance Example
class Animal:
    def sound(self):
        print("Animal sound")

class Dog(Animal):
    pass

d = Dog()
d.sound()

# Dog uses Animal method.
# Out:
# Animal sound

# %%
# Polymorphism Example
class Dog:
    def sound(self):
        print("Bark")

class Cat:
    def sound(self):
        print("Meow")

for a in [Dog(), Cat()]:
    a.sound()

# Same method name sound(), different behavior.
# Out:
# Bark
# Meow

# %%
# OOP Concepts (Very Easy)

# 1. Class
# A class is a blueprint or template used to create objects.
# Example: Car is a class.

# 2. Object
# An object is a real instance of a class.
# Example: BMW, Audi are objects of Car class.

# 3. Encapsulation
# Encapsulation means keeping data and methods together and protecting data from direct access.
# Example: ATM keeps bank data safe.

# 4. Abstraction
# Abstraction means hiding internal details and showing only important features.
# Example: Driving a car without knowing engine work.

# 5. Inheritance
# Inheritance means one class gets properties and methods of another class.
# Example: Dog inherits from Animal.

# 6. Polymorphism
# Polymorphism means same method name but different behavior.
# Example: Dog → Bark, Cat → Meow

# %%
# Abstraction

class payments:
    def pay(self):
        print('payments successfully')
        
p=payments()
p.pay()
# Out:
# payments successfully

# %%
# Encapsulation

class Account:
    def __init__(self,bal):
        self.__balance = bal 
    def show_balance(self):
        print('balance is :',self.__balance)    

acc = Account(5000)
acc.show_balance()
# Out:
# balance is : 5000

# %%
# Inheritance
# Parent class
class Vehicle:
    def start(self):
        print("Vehicle is starting")
# Child class 1
class Car(Vehicle):
    def drive(self):
        print("Car is now moving")
# Child class 2
class Bike(Vehicle):
    def ride(self):
        print("Bike is now riding")
# Child class 3
class Truck(Vehicle):
    def load(self):
        print("Truck is loading goods")
# Using the classes
c = Car()
c.start() # from parent
c.drive() # child specific
b = Bike()
b.start() # from parent
b.ride() # child specific
t = Truck()
t.start() # from parent
t.load() # child specific
# Out:
# Vehicle is starting
# Car is now moving
# Vehicle is starting
# Bike is now riding
# Vehicle is starting
# Truck is loading goods

# %%
# Polymorphism

class dog:
    def sound(self):
        print('Dog says: Bark')
class cat:
    def sound(self):
        print("Cat says: Meow")
class cow:
    def sound(self):
        print('Cow says: Moo')

# Polymorphism in action

Animals = [dog(),cat(),cow()]

for a in Animals:
    a.sound()
# Out:
# Dog says: Bark
# Cat says: Meow
# Cow says: Moo

# %%
class Circle:
    def area(self):
        print("Area = πr²")
class Square:
    def area(self):
        print("Area = side × side")
class Rectangle:
    def area(self):
        print("Area = length × width")

shapes = [Circle(),Square(),Rectangle()]

for a in shapes:
    a.area()
# Out:
# Area = πr²
# Area = side × side
# Area = length × width

# %%
# Practice – Build Account Class
# Task:
# Create an Account class with:
# ● Attributes → balance, account number
# ● Methods → debit, credit, print balance

class Account:
    def __init__(self,balance,acc_no):
        self.balance=balance
        self.acc_no=acc_no
    def credit(self,amount):
        self.balance+=amount
        print('Amount credit : ',amount)    
    def debit(self,amount):
        if amount <= self.balance:
            self.balance-=amount
            print("Amount debit :",amount)    
        else:
            print("Insufficient funds")    
    def show_balance(self):
        print("Account :",self.acc_no,"|balance :",self.balance)
        
a1 = Account(5000000000,'Amit')  
a1.credit(5000) 
a1.debit(9000)    
a1.show_balance()
# Out:
# Amount credit :  5000
# Amount debit : 9000
# Account : Amit |balance : 4999996000

# %%
# oops
# class
# object
# constructor
# special method __init__
# self
# self.a=a instance variable
# def method
# a=atm(123,4352) : - a is object
# object ke through methods access

# %%
# def raman():
#     print('hi')
# function outside the class
# function inside the class method
# self hamare object ko indicate karta hai ku kuki object class ka data store karta hai 
class ducat:
    def __init__(self,name,age):  #special method/magic method
        self.name=name #instance variable
        self.age=age
        print(self.name)
    def enroll(self):
        print('hi ducat student')
        
a=ducat('aditya',24)
# kisi bhi class me method ko access karna ho to object ke through call karte hai
a.enroll()
# Out:
# aditya
# hi ducat student

# %%
# calculator
# operations
# # collect the data from user
# num1
# num2
# user ham ye access denge ki wo konsa operation karna chahta hai
# add
# sub
# multiply
# result

# %%
# escape char\n,\t
class calculator:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
        print('\t\t\t\t\twelcome to calculator app')
        print('1) add\n2) sub\n3) multi')
        
    def operation_selection(self):
        select_option=int(input('select the option'))
        if select_option==1:
            user.add()
        elif select_option==2:
            user.sub()
        elif select_option==3:
            user.multi()
        else:
            print('invalid selection')
    def add(self):
        print(self.num1+self.num2)
    def sub(self):
        print(self.num1-self.num2)
    def multi(self):
        print(self.num1*self.num2)
user=calculator(10,20)
user.operation_selection()
# Out:
# 					welcome to calculator app
# 1) add
# 2) sub
# 3) multi
# 30

# %%
class calculator:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
        print("\t\t\t\tWelcome to Calculator app")
        print("1- add\n2- sub\n3- multi")
    def operation_selection(self):
        select_operation=int(input("Select the option"))
        if select_operation==1:
            user.add()
        elif select_operation==2:
            user.sub()
        elif select_operation==3:
            user.multi()
        else:
            print("Invalid selection")
    def add(self):
        print(self.num1+self.num2)
    def sub(self):
        print(self.num1-self.num2)
    def multi(self):
        print(self.num1*self.num2)
user=calculator(10,20)
user.operation_selection()
# Out:
# 				Welcome to Calculator app
# 1- add
# 2- sub
# 3- multi
# Invalid selection

# %%
class calculator:
    def __init__(self,num1,num2):
        self.num1=num1
        self.num2=num2
        print('\t\t\t\twelcom to calculator app')
        print('1)add\n2) sub\n3)multi')
    def operation_selection(self):  
        select_option=int(input('select the option'))
        if select_option==1:
            user.add()
        elif select_option==2:
            user.sub()
        elif select_option==3:
            user.multi()
        else:
            ('invalid selection')
    def add(self):
        print(self.num1+self.num2)
    def sub(self):
        print(self.num1-self.num2)
    def multi(self):
        print(self.num1*self.num2)
# user=calculator(10,20)2

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
user.operation_selection()
# Out:
# 30
