# %%
fruits = ['apple','mango','banana','cherry','blueberry']

# %%
fruits[0]
fruits[-1]
fruits[-2]
fruits[3]
# Out:
# 'cherry'

# %%
f = 'apple'
f[0]
# Out:
# 'a'

# %%
fruits[1:3]
# Out:
# ['mango', 'banana']

# %%
fruits[::-1]
# Out:
# ['blueberry', 'cherry', 'banana', 'mango', 'apple']

# %%
fruits
# Out:
# ['apple', 'mango', 'banana', 'cherry', 'blueberry']

# %%
fruits.append('oranger')

# %%
fruits
# Out:
# ['apple', 'mango', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits[1] = 'blackberry'

# %%
fruits
# Out:
# ['apple', 'blackberry', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits[0] = 'pineapple'
fruits[1] = 'banana'

# %%
fruits
# Out:
# ['oranger', 'blueberry', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits[0:2] = ['pineapple','banana']

# %%
fruits
# Out:
# ['pineapple', 'banana', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits
# Out:
# ['pineapple', 'banana', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits.insert(2,'pepsi')

# %%
fruits
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits.extend([1])

# %%
fruits
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana', 'cherry', 'blueberry', 'oranger', 1]

# %%
fruits.extend(['apple'])

# %%
fruits
# Out:
# ['pineapple',
#  'banana',
#  'pepsi',
#  'banana',
#  'cherry',
#  'blueberry',
#  'oranger',
#  1,
#  'apple']

# %%
fruits.append([1,2,3])

# %%
fruits
# Out:
# ['pineapple',
#  'banana',
#  'pepsi',
#  'banana',
#  'cherry',
#  'blueberry',
#  'oranger',
#  'apple']

# %%
fruits.remove(1)

# %%
fruits
# Out:
# ['pineapple',
#  'banana',
#  'pepsi',
#  'banana',
#  'cherry',
#  'blueberry',
#  'oranger',
#  1,
#  'apple']

# %%
fruits
# Out:
# ['pineapple',
#  'banana',
#  'pepsi',
#  'banana',
#  'cherry',
#  'blueberry',
#  'oranger',
#  'apple']

# %%
fruits.pop()
# Out:
# 'apple'

# %%
fruits
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana', 'cherry', 'blueberry', 'oranger']

# %%
fruits.pop()
# Out:
# 'cherry'

# %%
fruits
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana']

# %%
fruits
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana']

# %%
# del fruits

# %%
ff = fruits.copy()

# %%
ff
# Out:
# ['pineapple', 'banana', 'pepsi', 'banana']

# %%
fruits = ['apple','mango','banana','cherry','blueberry']

# %%
fruits
# Out:
# ['apple', 'mango', 'banana', 'cherry', 'blueberry']

# %%
for i in fruits:
    print(i)
# Out:
# apple
# mango
# banana
# cherry
# blueberry

# %%
for i in fruits:
    if 'r' in i:
        print(i)
# Out:
# cherry
# blueberry
