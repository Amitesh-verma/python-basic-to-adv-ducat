# %% [markdown]
# # sets

# %% [markdown]
# 1. syntax {}
#
# 2. contain unique elemets
#
# 3. unordered
#
# 4. contains multiple data types

# %%
ss ={1,2,4,1,False,'s',5} 
type(ss)
# Out:
# set

# %%
ss
# Out:
# {1, 2, 4, 5, False, 's'}

# %%
ss[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ss[1]
#
# TypeError: 'set' object is not subscriptable

# %%
# wap to check duplicated from given list 

apple = ['x','11pro','11plue','12','12pro','x','11pro']

apple = list(set(apple))

apple
# Out:
# ['11pro', 'x', '11plue', '12', '12pro']

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# banana
# apple
# cherry

# %%
thisset.add('mango')
thisset
# Out:
# {'apple', 'banana', 'cherry', 'mango'}

# %%
thisset.update(apple)
thisset
# Out:
# {'11plue', '11pro', '12', '12pro', 'apple', 'banana', 'cherry', 'mango', 'x'}

# %%
# thisset = {'apple','banana','cherry'}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# 11pro
# {'apple', '12pro', 'banana', 'x', 'mango', '11plue', '12', 'cherry'}

# %%
x = frozenset({'apple','banana',})
