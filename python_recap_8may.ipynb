# %%
# # variable
# # data store
# a=10
# # a:- variable and 10 data 
# # variable rules
# # 4 rules
# 2a=10  #can't start with int
# raman tiwari=10 #not use spaces
# $raman%=10  #except underscore
# def=10 #reserved keyword nhi kar sakte

# %%
# data type  2
# user define and builtin data type
  # user will create and 
# builtin data type
# string
# list
# tuple
# set
# dictionary
# boolean:- True , False
# number:-int,float,complex

# %%
# number 
a=10
# findout with type function
# print(type(a))
# address id function
# print(id(a))
# type casting
# int convert float
# b=float(a)
# print(b)
c=str(a)
print(c)
# Out:
# 10

# %%
# string data type
# immutable  string,tuple,
# mutable 
# indexing
# positive always start with 0
a='python'
 # 012345
# print(a[0])
# negative indexing
a='python'
 # -6-54-3-2-1
print(a[-1])
# Out:
# n

# %%
# slicing
# start:end+1:step+1
a='python' #pn
 # 012345
# print(a[0:5+1:4+1])

# %%
# indexing slicing

# %%
# methods in string
a=''
a=""
a'''sdf'''
# upper()
a='raman'
a.upper()
# lower()
# replace()
a.replace('r','t')
# index()
# startswith()
a.startswith('y')
# endswith()
# Out:
# False

# %%
# list
# mutable
# list store multiple 
a=[1,2,'raman']
print(a[2])
# Out:
# raman

# %%
# methods
# append()
a=[1,2,3,4,5]
a.append(6)
print(a)
# pop()
# insert()
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# tuple
a=(1,2,3,4)
# indexing

# %%
# set()
a={1,2,3,4}
# indexing nhi hoti

# %%
# dictionary
# key:value
a={
    'name':'raman',
    'company':'ducat'
}
# data access
print(a['name'])
# Out:
# raman

# %%
# operators
# arithmetic operator:-+,-,*,**,/,//,%
print(10/2)
print(10//2)
print(10%3)
# assignemnt
# =
a=10
# logical
# and or ,not
# membership
# in ,not in
a='raman'
print('t' in a)
# Out:
# 5.0
# 5
# 1
# False

# %%
# if else condition
if 100==100:
    print('sahi hai')
else:
    print('kuch gadbar hai')
# Out:
# sahi hai

# %%
# multiple condition
# elif
if 100==200:
    print('hi')
elif 100>300:
    print('no')
elif 100==1000:
    print('good')
else:
    print('done')
# Out:
# done

# %%
# for loop
# iteration
# step by step data split karna
a='abc'
for i in a:
    if i=='c':
        break
    print(i,end='')
# Out:
# ab

# %%
# while
# while

# %%
# def function
def raman(a,b): #parameter
    print(a+b)
raman(10,20) #arguments
# Out:
# 30

# %%
# default parameter
def raman(name='ducat'):
    print(name)
raman('company')
# Out:
# company

# %%
# args and kwargs
# ek single variable multiple data ko store kare usi ko args but variable ke aage * hona chahiye
def rt(*a):
    print(a[1])
rt(1,2,3,4,5)
# Out:
# 2

# %%
# kwargs
def ty(**a):
    print(a['company'])
ty(name='raman',company='ducat')
# Out:
# ducat

# %%
# doc string
def gt():
    '''hi this is adding function'''
    print(100+200)
gt()
# Out:
# 300

# %%
print(gt.__doc__)
# Out:
# hi this is adding function

# %%
# print and return
# data hold nhi karta and return data hold karta hai

# %%
# file handling
# file create
# file data write
# file read
# 'r'
# 'w'
# 'a'
# 'x'
# g=open(r'path','w')
# g.write('hi')
# g.close()
# with open(r'path',mode) as f:
#     f.write('hi class')

# %%
# import module
# india.py
# from usa import iphone
# import usa 
# print(usa.iphone)
# usa.py

# %%
# try except
# error handling
# try block police
# except block 
# else 
# finally

# %%
try:
    print(hi)
except:
    print('haanji')
# Out:
# haanji

# %%
# oops
class raman:
    def __init__(self,a,b): #special method
        self.a=a #instance variable
        self.b=b
        print('hi all')
    def ty(self):
        print('hi')
n=raman(10,20)
# object ke through method call karte hai
n.ty()
# Out:
# hi all
# hi
